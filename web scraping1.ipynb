# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import csv

# %%
from datetime import datetime

# %%
url_page= "https://encuentromundialbigdata.com/2019/entradas/"
# se coloca este headers para que piense el servidor que la solicitud viene de un browser
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
page= requests.get(url_page, headers=headers).text
soup= BeautifulSoup(page,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-CO">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    IV Encuentro Mundial Big Data 2019 |   Reserve ahora sus entradas
#   </title>
#   <meta content="width=device-width,initial-scale=1,user-scalable=no" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://encuentromundialbigdata.com/2019/xmlrpc.php" rel="pingback"/>
#   <link href="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/favicon.png" rel="apple-touch-icon"/>
#   <link href="//fonts.googleapis.com/css?family=Raleway:100,200,300,400,500,600,700,800,900,300italic,400italic,700italic|Work+Sans:100,200,300,400,500,600,700,800,900,300italic,400italic,700italic&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#   <script type="application/javascript">
# ...

# %%
title = soup.title.string

# %%
print (title) # nos devuelve el titulo de la paguina web
# Out:
# IV Encuentro Mundial Big Data 2019 |   Reserve ahora sus entradas

# %%
link=soup.select("body p > a") # para buscar todos los link de la paguna web

# %%
print(link)
# Out:
# [<a href="https://encuentromundialbigdata.com/2019/conferencistas/">Convocatoria para conferencistas.</a>, <a href="https://encuentromundialbigdata.com/2019/patrocinadores/">Participe como <em>sponsor.</em></a>, <a href="tel://+5715833900">571 583 3900</a>, <a href="tel://+573017392232">301 739 2232</a>, <a href="https://encuentromundialbigdata.com/2019/patrocinadores/">Ver propuesta comercial</a>]

# %%
prices=soup.find_all("div") # para buscar las div o "a"

# %%
print(prices)
# Out:
# [<div class="widget_text widget widget_custom_html posts_holder" id="custom_html-8"><div class="textwidget custom-html-widget"><div class="separator transparent " style="margin-top: 0px;"></div>
# </div></div>, <div class="textwidget custom-html-widget"><div class="separator transparent " style="margin-top: 0px;"></div>
# </div>, <div class="separator transparent " style="margin-top: 0px;"></div>, <div class="widget widget_media_image posts_holder" id="media_image-3"><img alt="Encuentro Mundial Big Data" class="image wp-image-464 attachment-157x50 size-157x50" height="42" src="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/EMBD-blanco.png" style="max-width: 100%; height: auto;" width="157"/></div>, <div class="widget widget_text posts_holder" id="text-4"> <div class="textwidget"><div class="separator transparent " style="margin-top: -21px;"></div>
# ...

# %%
palabra=soup.find_all("div",attrs={"class":"q_logo"}) # se trae la informacion de todo lo q esta entre div class q_logo

# %%
print(palabra)
# Out:
# [<div class="q_logo">
# <a href="https://encuentromundialbigdata.com/2019/" itemprop="url">
# <img alt="Logo" class="normal" itemprop="image" src="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/EMBD-blanco.png"/> <img alt="Logo" class="light" itemprop="image" src="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/EMBD.png"/> <img alt="Logo" class="dark" itemprop="image" src="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/EMBD-blanco.png"/> <img alt="Logo" class="sticky" itemprop="image" src="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/EMBD.png"/> <img alt="Logo" class="mobile" itemprop="image" src="https://encuentromundialbigdata.com/2019/wp-content/uploads/2018/11/EMBD.png"/> </a>
# </div>]

# %%
palabra2=soup.find_all("div",attrs={"class":"price_table_inner"})

# %%
print(palabra2)
# Out:
# [<div class="price_table_inner"><ul><li class="cell table_title"><h3 class="qode_title_content_new">Full access</h3></li><li class="prices"><div class="price_in_table"><sup class="value">COP</sup><span class="price">1.400.000</span><span class="mark">+IVA</span></div></li><li class="pricing_table_content">
# <ul>
# <li><strong>Agenda principal</strong></li>
# <li><strong>Agenda Mejores Prácticas</strong></li>
# <li><strong>Encuentro Global de Centros de Investigación e Innovación</strong></li>
# <li>Acceso a muestra comercial</li>
# <li>Kit especial de bienvenida</li>
# <li>Refrigerios AM los dos días del evento</li>
# <li>Estación de café</li>
# <li>Certificado de asistencia</li>
# </ul>
# ...

# %%
palabra3=soup.find_all("span",attrs={"class":"price"}) #Etiqueta span

# %%
print(palabra3)
# Out:
# [<span class="price">1.400.000</span>, <span class="price">980.000</span>, <span class="price">910.000</span>, <span class="price">80.000</span>]

# %%
palabra4=soup.find("span",attrs="price").getText() # encuentra la primera de los precios

# %%
print(palabra4)
# Out:
# 1.400.000

# %%
palabra5= soup.find("h3", attrs={"class": "qode_title_content_new"}).getText()

# %%
print(palabra5)
# Out:
# Full access

# %%
palabra6 = soup.find("li") # trae el primer li

# %%
print(palabra6)
# Out:
# <li class="menu-item menu-item-type-post_type menu-item-object-page narrow" id="nav-menu-item-1088"><a class="" href="https://encuentromundialbigdata.com/2019/evento/"><i class="menu_icon blank fa"></i><span>El evento</span><span class="plus"></span></a></li>

# %%
# para buascar el TRM https://dolar.wilkinsonpc.com.co con inspeccionar se ubica la variable mas facil en el browser
url_page= "https://dolar.wilkinsonpc.com.co"
# se coloca este headers para que piense el servidor que la solicitud viene de un browser
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
page= requests.get(url_page, headers=headers).text
soup= BeautifulSoup(page,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Precio del Dolar Hoy en Colombia - Lunes  $3,270.70 - Cotizacion del dolar
#   </title>
#   <meta content="Conozca el precio del dolar hoy en Colombia, conozca el valor del dolar TRM del dia, suscribase a la lista de correos para recibir a diario la informaicon del dolar hoy." name="description"/>
#   <meta content="dolar hoy, dolar colombia, dolar precio, pesos por dolar, valor dolar colombia, $3,270.70, precio del dolar, precio del dolar en colombia, cotizacion dolar, cambio dolar, valor del dolar, dolar futuro, dolar historico, Dolar HOY, Cotizacion del dolar colombia, Historico Dolar, Dolar en Colombia, valor de la TRM, Dolar IFX" name="keywords"/>
#   <link href="https://dolar.wilkinsonpc.com.co" rel="canonical"/>
# ...

# %%
valortrm= soup.find("span", attrs={"class": "numero"}).getText()

# %%
print(valortrm)
# Out:
# 3,287.07*

# %%
valortrm= valortrm[:-1]

# %%
print(valortrm)
# Out:
# 3,287.07

# %%
valortrm= valortrm.replace(",","")

# %%
print(valortrm)
# Out:
# 3287.07

# %%
valortrm= float(valortrm)

# %%
mas=valortrm + 2

# %%
print(mas)
# Out:
# 3289.07

# %%
encabezado="Valor"

# %%
with open("archivoTRM.csv","a") as csv_file:  # escribir una en el archivo csv
    escribir= csv.writer(csv_file)
    escribir.writerow([encabezado]) # en []para que sea en una celda
    escribir.writerow([valortrm])
